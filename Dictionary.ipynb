# %%
# Recap on dictionary
# It can take both string and integer
lst = ["baraka", 2, "danie", 3]

# %%
lst # Calling the list
# Out:
# ['baraka', 2, 'danie', 3]

# %%
student = ["English", 30 ,"Math", 45] # Example of list with string and interger

# %%
#Syntax for dictionary
{"Key":"values",
 "key2":"value"
 }

# %%
{"Baraka":245} # example of a simple dictionary

# %%
# Example of a more than one key
student = {
    "name": "Alice",
    "age": 20,
    "grade": "A",
    "location":"Nairobi"
}

# %%
student["age"] # accessing values in a dictionary
# Out:
# 20

# %%
student["school"]="Moringa" # Adding new element to the dictionary

# %%
student #calling the dictionary
# Out:
# {'name': 'Alice',
#  'age': 20,
#  'grade': 'A',
#  'location': 'Nairobi',
#  'school': 'Moringa'}

# %%
student["subjects"] = ["Python","Java","Ml"] # Adding a list to the dictionary with key subjects

# %%
student['Friends'] = ["Anto", 'Noah', "Daniel", "Kiptoo"] # Adding another dictionary to with key Friends

# %%
student
# Out:
# {'name': 'Alice',
#  'age': 20,
#  'grade': 'A',
#  'location': 'Nairobi',
#  'school': 'Moringa',
#  'subjects': ['Python', 'Java', 'Ml'],
#  'Friends': ['Anto', 'Noah', 'Daniel', 'Kiptoo']}

# %%
student['Friends'] # Accesing friends
# Out:
# ['Anto', 'Noah', 'Daniel', 'Kiptoo']

# %%
type(student)
# Out:
# dict

# %%
student.keys() # This gives us all the keys in a dictionary
# Out:
# dict_keys(['name', 'age', 'grade', 'location', 'school', 'subjects', 'Friends'])

# %%
student.values() # All values of a dictionary
# Out:
# dict_values(['Alice', 20, 'A', 'Nairobi', 'Moringa', ['Python', 'Java', 'Ml'], ['Anto', 'Noah', 'Daniel', 'Kiptoo']])

# %%
student
# Out:
# {'name': 'Alice',
#  'age': 20,
#  'grade': 'A',
#  'location': 'Nairobi',
#  'school': 'Moringa',
#  'subjects': ['Python', 'Java', 'Ml']}

# %%
# A new dictionary that is to be added to another dictionary
dataset_info = {
    "num_rows": 1000,
    "num_columns": 15,
    "columns": ["age", "gender", "income", "education"],
    "description": "Demographic and financial data."
}

# %%
data = [student,dataset_info] # Joining two dictionaries

# %%
data
# Out:
# [{'name': 'Alice',
#   'age': 20,
#   'grade': 'A',
#   'location': 'Nairobi',
#   'school': 'Moringa',
#   'subjects': ['Python', 'Java', 'Ml'],
#   'Friends': ['Anto', 'Noah', 'Daniel', 'Kiptoo']},
#  {'num_rows': 1000,
#   'num_columns': 15,
#   'columns': ['age', 'gender', 'income', 'education'],
#   'description': 'Demographic and financial data.'}]

# %%
data[1]['columns'][2] #Accessing dictionary in a list of dictionary
# Out:
# 'income'

# %% [markdown]
# Arithmetics

# %%
# * + -
#// floor - qout
#/ division
#!= not equal
# == equal
# % rem

# %%
2*2 # multiplication
# Out:
# 4

# %%
2+3 # addition
# Out:
# 5

# %%
10-5 # subtraction
# Out:
# 5

# %%
15 / 2 # division
# Out:
# 7.5

# %%
19 // 10 # Qou
# Out:
# 1

# %%
19 % 10 # rem
# Out:
# 9

# %%
 5 == 5 # its equal
# Out:
# True

# %%
3 == 7
# Out:
# False

# %%
2 != 6 # is not equal to
# Out:
# True

# %%
# If conditions using arithmetics check if its even or odd
numbers = 15
if numbers%2 == 0:
  print("Number is even")
else:
  print("Number is odd")
# Out:
# Number is odd

# %%
# using it's not equal to operator
banana = 100
if banana != 50:
  print("Go home")
else:
  print("sit")
# Out:
# Go home

# %%
# Python inbuilt method

# type
# print
# title
# upper
# lower
# capitalize

# %%
# convert to lower case
name = "ANTHONY"
name_lower = name.lower()
name_lower
# Out:
# 'anthony'

# %%
# Capitalize the first letter
name = 'nOAHE'
name.capitalize()
# Out:
# 'Noahe'

# %%
# Class example to access 91

student_grades = {
    "Alice": {"Math": 90, "English": 85, "Science": 88},
    "Bob": {"Math": 78, "English": 82, "Science": 79},
    "Charlie": {"Math": 92, "English": 91, "Science": 94}
}

# %%
student_grades['Charlie']['English'] #Accessing 91
# Out:
# 91

# %%
# Example 2 print out Statistics

employees = [
    {
        "name": "Alice",
        "position": "Software Engineer",
        "skills": ["Python", "JavaScript", "SQL"]
    },
    {
        "name": "Bob",
        "position": "Data Scientist",
        "skills": ["Python", "Machine Learning", "Statistics"]
    },
    {
        "name": "Charlie",
        "position": "Product Manager",
        "skills": ["Project Management", "Agile", "Communication"]
    }
]

# %%
employees[1]['skills'][2] # Accessing Statistics
# Out:
# 'Statistics'

# %% [markdown]
# If condition to check whether a number is a prime number within the range of 1 - 57

# %%
# am doing summation
x = 2+3 # I expect a 5
x # Hurray
# Out:
# 5

# %%
# More example
# Use it for your practice

students = [
    {
        "name": "Alice",
        "age": 20,
        "subjects": [
            {"subject": "Math", "grade": 90},
            {"subject": "Science", "grade": 85},
            {"subject": "History", "grade": 88}
        ]
    },
    {
        "name": "Bob",
        "age": 22,
        "subjects": [
            {"subject": "Math", "grade": 78},
            {"subject": "Science", "grade": 82},
            {"subject": "Literature", "grade": 79}
        ]
    },
    {
        "name": "Charlie",
        "age": 21,
        "subjects": [
            {"subject": "Math", "grade": 95},
            {"subject": "Science", "grade": 90},
            {"subject": "Art", "grade": 92}
        ]
    }
]

# %%
students[0]
# Out:
# {'name': 'Alice',
#  'age': 20,
#  'subjects': [{'subject': 'Math', 'grade': 90},
#   {'subject': 'Science', 'grade': 85},
#   {'subject': 'History', 'grade': 88}]}

# %%
students[0]['subjects'][1]
# Out:
# {'subject': 'Science', 'grade': 85}
